# %% [markdown]
# ## Esse é um pequeno projeto de raspagem de dados do GitHub sobre os 10 projetos mais populares do GitHub.

# %%
import os

username = "Lucas89Renan" #
os.environ["GITHUB_USER"] = username

# !git config --global user.name "${GITHUB_USER}"

# %%
import os
from getpass import getpass

usermail = getpass()
os.environ["GITHUB_MAIL"] = usermail

# !git config --global user.email "${GITHUB_MAIL}"
# Out:
# ··········

# %%
import os
from getpass import getpass

usertoken = getpass()
os.environ["GITHUB_TOKEN"] = usertoken
# Out:
# ··········

# %%
# !git clone https://${GITHUB_USER}:${GITHUB_TOKEN}@github.com/Lucas89Renan/Projetos.git
# Out:
# Cloning into 'Projetos'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 19 (delta 4), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (19/19), 583.74 KiB | 4.32 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
# %cd Projetos
# Out:
# /content/Projetos/Projetos

# %% [markdown]
# ## IMPORTANDO PACOTES
# ```

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from requests.exceptions import HTTPError

# %% [markdown]
# ## Verificando o Robots.txt

# %%
requerimento = None
URL = 'https://github.com/trending/robots.txt'
try:
    requerimento = requests.get(URL)
    requerimento.raise_for_status()

except HTTPError as exc:
  print(exc)

else:
    requerimento = requerimento.text
print(requerimento)

# %% [markdown]
# ## Trazendo os dados

# %%
requerimento = None
URL = 'https://github.com/trending'
try:
    requerimento = requests.get(URL)
    requerimento.raise_for_status()

except HTTPError as exc:
  print(exc)

else:
    requerimento = requerimento.text
print(requerimento)

# %%
pagina = BeautifulSoup(requerimento, 'html.parser')

print(pagina.prettify())

# %% [markdown]
# ### Filtrando apenas os dados dos projetos

# %%
projetos = pagina.find_all('article',class_='Box-row')[:10]

# %%
top_projetos = []

for projeto in projetos:

  #titulo dos projetos
  titulo = projeto.find('h2', class_='h3 lh-condensed').text.strip()
  titulo = titulo.replace('\n','').replace('\t','').replace('/', ',').replace('     ', '')

  #linguagem de programação
  linguagem = projeto.find('span', class_='d-inline-block ml-0 mr-3').text.strip()

  #estrelas totais
  stars = projeto.find('a', class_='Link Link--muted d-inline-block mr-3').text.strip()

  #estrelas hoje
  stars_today = projeto.find('span', class_='d-inline-block float-sm-right').text.strip()
  stars_today = stars_today.replace('stars today', '')


  #forks
  forks = projeto.find('a', class_='Link Link--muted d-inline-block mr-3').text.strip()

  top_projetos.append([titulo, linguagem, stars, stars_today, forks])

# %% [markdown]
# ## Convertendo em um DataFrame

# %%
df_projeto = pd.DataFrame(top_projetos, columns = ['Título', 'Linguagem', 'Estrelas Hoje', 'Estrelas Totais', 'Forks'])

# %%
df_projeto['Ranking'] = range(1,11)

# %%
df_projeto
# Out:
#                                Título         Linguagem Estrelas Hoje  \
# 0                 Cinnamon , kotaemon            Python         8,280
# 1              sickcodes , Docker-OSX             Shell        44,169
# 2                 lobehub , lobe-chat        TypeScript        37,801
# 3         f , awesome-chatgpt-prompts              HTML       109,117
# 4              aceberg , WatchYourLAN                Go         2,450
# 5                MLSysOps , MLE-agent            Python           584
# 6            graviraja , MLOps-Basics  Jupyter Notebook         4,793
# 7              gitroomhq , postiz-app        TypeScript         4,498
# 8  swisskyrepo , PayloadsAllTheThings            Python        59,635
# 9         bluesky-social , social-app        TypeScript         7,761
#
#   Estrelas Totais    Forks  Ranking
# 0          1,375     8,280        1
# 1          1,244    44,169        2
# 2             52    37,801        3
# 3            195   109,117        4
# ...

# %% [markdown]
# ## Por fim conversão para um arquivo csv

# %%
df_projeto.to_csv('top_Projetos-github.csv')

# %%
# !git branch
# Out:
# * main

# %%
# !git add .

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git commit -m "Adicionando arquivo Top_Projetos-github.csv"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git push origin main
# Out:
# Everything up-to-date
